# %%
import requests

url = "https://mashape-community-skate-ipsum.p.rapidapi.com/3/1/JSON"

headers = {
    'x-rapidapi-host': "mashape-community-skate-ipsum.p.rapidapi.com",
    'x-rapidapi-key': "356fcb635fmsh9767f12c6c5229bp110c7ejsnf22feaa0d4a2"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# ["Skate ipsum dolor sit amet,  coper gnarly nose grab regular footed slide. Bruised heel judo air bigspin flail 540. Bigspin pump skate or die crail grab quarter pipe. Alternative Sports gnar bucket wall ride wheels lien air wax. Switch downhill hurricane egg plant Transworld pool. Wheels casper slide sick rail slide carve. Vision gnarly bluntslide flail layback mute-air. Rails deck slap maxwell death box rail. Masonite grind Christ air flypaper rip grip. ","John Lucero gnar bucket sick aerial front foot impossible. Berm shinner cab flip skate key. Casper slam disaster 900. Aerial bearings face plant boned out. Impossible Christ air kingpin Saran Wrap. Front foot impossible salad grind hang ten Sidewalk Surfer bone air. Chris Haslam rail slide deck grab varial. Love Bowl kick-nose powerslide pivot mute-air. Late ledge dude Primo slide. Andy Levy tail slide hurricane cab flip. Goofy footed Tracker feeble 720. Heel flip casper hang ten Neal Hendrix soul skate. Axle skater death box nose grab. ","Disaster melancholy ledge axle set bone air coffin Eight Dayz slam. Grind axle hanger mini ramp no comply 360 hurricane. Tracker flypaper poseur slap maxwell crail slide bank Sean Cliver frontside. Coper casper slide pivot nosegrind crailtap regular footed hurricane Natas Kaupas. Hip slappy deck bearings stoked betty grind. Casper 1080 lip tail vert Ray Underhill boned out full-cab. Steps frigid air judo air slam kickturn heel flip Skate Rock melancholy. 180 rocket air pump Eight Dayz bearings nose slide 900 ho-ho. Kingpin concave griptape kickturn Kevin Staab fastplant carve mini ramp. Berm NoMeansNo bank feeble gap backside Saran Wrap skater. Kick-nose deck lip poseur nosepicker flypaper slob air. Airwalk hard flip rad shinner varial boned out stalefish Streets on Fire. "]

# %%
import requests

cities = ['London,uk', 'Paris,fr', 'Porto,pt']
weather_dict = {}

def city_forecast(city):
    url = "https://community-open-weather-map.p.rapidapi.com/forecast"
    querystring = {"q":city}
    headers = {
        'x-rapidapi-host': "community-open-weather-map.p.rapidapi.com",
        'x-rapidapi-key': "356fcb635fmsh9767f12c6c5229bp110c7ejsnf22feaa0d4a2"
        }
        
    response = requests.request("GET", url, headers=headers, params=querystring)
    return response.json()

# %%
city_forecast("Seoul,kr")
# Out:
# {'city': {'coord': {'lat': 37.5683, 'lon': 126.9778},
#   'country': 'KR',
#   'id': 1835848,
#   'name': 'Seoul',
#   'population': 10349312,
#   'sunrise': 1634247586,
#   'sunset': 1634288144,
#   'timezone': 32400},
#  'cnt': 40,
#  'cod': '200',
#  'list': [{'clouds': {'all': 74},
#    'dt': 1634288400,
#    'dt_txt': '2021-10-15 09:00:00',
#    'main': {'feels_like': 294.4,
#     'grnd_level': 1011,
#     'humidity': 49,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'temp': 294.89,
#     'temp_kf': -0.25,
#     'temp_max': 295.14,
#     'temp_min': 294.89},
#    'pop': 0.2,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'broken clouds',
#      'icon': '04n',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 330, 'gust': 2.15, 'speed': 1.25}},
#   {'clouds': {'all': 80},
#    'dt': 1634299200,
#    'dt_txt': '2021-10-15 12:00:00',
#    'main': {'feels_like': 293.83,
#     'grnd_level': 1012,
#     'humidity': 56,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'temp': 294.21,
#     'temp_kf': 0.28,
#     'temp_max': 294.21,
#     'temp_min': 293.93},
#    'pop': 0.33,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'broken clouds',
#      'icon': '04n',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 340, 'gust': 4.1, 'speed': 2.49}},
#   {'clouds': {'all': 100},
#    'dt': 1634310000,
#    'dt_txt': '2021-10-15 15:00:00',
#    'main': {'feels_like': 291.79,
#     'grnd_level': 1012,
#     'humidity': 67,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'temp': 292.09,
#     'temp_kf': 0,
#     'temp_max': 292.09,
#     'temp_min': 292.09},
#    'pop': 0.51,
#    'rain': {'3h': 0.3},
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'light rain',
#      'icon': '10n',
#      'id': 500,
#      'main': 'Rain'}],
#    'wind': {'deg': 316, 'gust': 4.11, 'speed': 2.33}},
#   {'clouds': {'all': 100},
#    'dt': 1634320800,
#    'dt_txt': '2021-10-15 18:00:00',
#    'main': {'feels_like': 288.97,
#     'grnd_level': 1013,
#     'humidity': 40,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'temp': 290.17,
#     'temp_kf': 0,
#     'temp_max': 290.17,
#     'temp_min': 290.17},
#    'pop': 0.55,
#    'rain': {'3h': 0.58},
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'light rain',
#      'icon': '10n',
#      'id': 500,
#      'main': 'Rain'}],
#    'wind': {'deg': 310, 'gust': 7.4, 'speed': 4.51}},
#   {'clouds': {'all': 100},
#    'dt': 1634331600,
#    'dt_txt': '2021-10-15 21:00:00',
#    'main': {'feels_like': 286.15,
#     'grnd_level': 1014,
#     'humidity': 47,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'temp': 287.44,
#     'temp_kf': 0,
#     'temp_max': 287.44,
#     'temp_min': 287.44},
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'overcast clouds',
#      'icon': '04n',
#      'id': 804,
#      'main': 'Clouds'}],
#    'wind': {'deg': 313, 'gust': 11.3, 'speed': 4.98}},
#   {'clouds': {'all': 100},
#    'dt': 1634342400,
#    'dt_txt': '2021-10-16 00:00:00',
#    'main': {'feels_like': 283.8,
#     'grnd_level': 1016,
#     'humidity': 24,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'temp': 285.85,
#     'temp_kf': 0,
#     'temp_max': 285.85,
#     'temp_min': 285.85},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'overcast clouds',
#      'icon': '04d',
#      'id': 804,
#      'main': 'Clouds'}],
#    'wind': {'deg': 309, 'gust': 9.64, 'speed': 5.75}},
#   {'clouds': {'all': 100},
#    'dt': 1634353200,
#    'dt_txt': '2021-10-16 03:00:00',
#    'main': {'feels_like': 283.32,
#     'grnd_level': 1016,
#     'humidity': 18,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'temp': 285.55,
#     'temp_kf': 0,
#     'temp_max': 285.55,
#     'temp_min': 285.55},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'overcast clouds',
#      'icon': '04d',
#      'id': 804,
#      'main': 'Clouds'}],
#    'wind': {'deg': 314, 'gust': 9.49, 'speed': 7.08}},
#   {'clouds': {'all': 97},
#    'dt': 1634364000,
#    'dt_txt': '2021-10-16 06:00:00',
#    'main': {'feels_like': 282.79,
#     'grnd_level': 1015,
#     'humidity': 21,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'temp': 285,
#     'temp_kf': 0,
#     'temp_max': 285,
#     'temp_min': 285},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'overcast clouds',
#      'icon': '04d',
#      'id': 804,
#      'main': 'Clouds'}],
#    'wind': {'deg': 320, 'gust': 10.24, 'speed': 7.66}},
#   {'clouds': {'all': 92},
#    'dt': 1634374800,
#    'dt_txt': '2021-10-16 09:00:00',
#    'main': {'feels_like': 278.31,
#     'grnd_level': 1018,
#     'humidity': 30,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'temp': 281.79,
#     'temp_kf': 0,
#     'temp_max': 281.79,
#     'temp_min': 281.79},
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'overcast clouds',
#      'icon': '04n',
#      'id': 804,
#      'main': 'Clouds'}],
#    'wind': {'deg': 318, 'gust': 11.96, 'speed': 7.12}},
#   {'clouds': {'all': 70},
#    'dt': 1634385600,
#    'dt_txt': '2021-10-16 12:00:00',
#    'main': {'feels_like': 275.86,
#     'grnd_level': 1020,
#     'humidity': 31,
#     'pressure': 1027,
#     'sea_level': 1027,
#     'temp': 279.87,
#     'temp_kf': 0,
#     'temp_max': 279.87,
#     'temp_min': 279.87},
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'broken clouds',
#      'icon': '04n',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 320, 'gust': 12.14, 'speed': 7.05}},
#   {'clouds': {'all': 26},
#    'dt': 1634396400,
#    'dt_txt': '2021-10-16 15:00:00',
#    'main': {'feels_like': 273.46,
#     'grnd_level': 1022,
#     'humidity': 30,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'temp': 277.92,
#     'temp_kf': 0,
#     'temp_max': 277.92,
#     'temp_min': 277.92},
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03n',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 326, 'gust': 12.59, 'speed': 6.75}},
#   {'clouds': {'all': 13},
#    'dt': 1634407200,
#    'dt_txt': '2021-10-16 18:00:00',
#    'main': {'feels_like': 272.16,
#     'grnd_level': 1022,
#     'humidity': 29,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'temp': 276.57,
#     'temp_kf': 0,
#     'temp_max': 276.57,
#     'temp_min': 276.57},
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'few clouds',
#      'icon': '02n',
#      'id': 801,
#      'main': 'Clouds'}],
#    'wind': {'deg': 323, 'gust': 11.43, 'speed': 5.74}},
#   {'clouds': {'all': 0},
#    'dt': 1634418000,
#    'dt_txt': '2021-10-16 21:00:00',
#    'main': {'feels_like': 271.93,
#     'grnd_level': 1022,
#     'humidity': 29,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'temp': 275.82,
#     'temp_kf': 0,
#     'temp_max': 275.82,
#     'temp_min': 275.82},
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 333, 'gust': 7.22, 'speed': 4.35}},
#   {'clouds': {'all': 0},
#    'dt': 1634428800,
#    'dt_txt': '2021-10-17 00:00:00',
#    'main': {'feels_like': 275.72,
#     'grnd_level': 1023,
#     'humidity': 22,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'temp': 277.85,
#     'temp_kf': 0,
#     'temp_max': 277.85,
#     'temp_min': 277.85},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 334, 'gust': 4, 'speed': 2.47}},
#   {'clouds': {'all': 0},
#    'dt': 1634439600,
#    'dt_txt': '2021-10-17 03:00:00',
#    'main': {'feels_like': 280.55,
#     'grnd_level': 1021,
#     'humidity': 14,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'temp': 282.29,
#     'temp_kf': 0,
#     'temp_max': 282.29,
#     'temp_min': 282.29},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 321, 'gust': 4.23, 'speed': 3.13}},
#   {'clouds': {'all': 0},
#    'dt': 1634450400,
#    'dt_txt': '2021-10-17 06:00:00',
#    'main': {'feels_like': 282.04,
#     'grnd_level': 1019,
#     'humidity': 16,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'temp': 284.44,
#     'temp_kf': 0,
#     'temp_max': 284.44,
#     'temp_min': 284.44},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 313, 'gust': 5.14, 'speed': 4.2}},
#   {'clouds': {'all': 0},
#    'dt': 1634461200,
#    'dt_txt': '2021-10-17 09:00:00',
#    'main': {'feels_like': 280.36,
#     'grnd_level': 1019,
#     'humidity': 24,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'temp': 282.53,
#     'temp_kf': 0,
#     'temp_max': 282.53,
#     'temp_min': 282.53},
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 319, 'gust': 5.32, 'speed': 4.07}},
#   {'clouds': {'all': 0},
#    'dt': 1634472000,
#    'dt_txt': '2021-10-17 12:00:00',
#    'main': {'feels_like': 279.15,
#     'grnd_level': 1020,
#     'humidity': 30,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'temp': 281.13,
#     'temp_kf': 0,
#     'temp_max': 281.13,
#     'temp_min': 281.13},
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 328, 'gust': 5.79, 'speed': 3.13}},
#   {'clouds': {'all': 0},
#    'dt': 1634482800,
#    'dt_txt': '2021-10-17 15:00:00',
#    'main': {'feels_like': 280.68,
#     'grnd_level': 1020,
#     'humidity': 32,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'temp': 280.68,
#     'temp_kf': 0,
#     'temp_max': 280.68,
#     'temp_min': 280.68},
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 337, 'gust': 3.58, 'speed': 1.12}},
#   {'clouds': {'all': 0},
#    'dt': 1634493600,
#    'dt_txt': '2021-10-17 18:00:00',
#    'main': {'feels_like': 280.4,
#     'grnd_level': 1018,
#     'humidity': 34,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'temp': 280.4,
#     'temp_kf': 0,
#     'temp_max': 280.4,
#     'temp_min': 280.4},
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 114, 'gust': 1.14, 'speed': 0.86}},
#   {'clouds': {'all': 52},
#    'dt': 1634504400,
#    'dt_txt': '2021-10-17 21:00:00',
#    'main': {'feels_like': 280.41,
#     'grnd_level': 1018,
#     'humidity': 36,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'temp': 280.94,
#     'temp_kf': 0,
#     'temp_max': 280.94,
#     'temp_min': 280.94},
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'broken clouds',
#      'icon': '04n',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 115, 'gust': 1.91, 'speed': 1.39}},
#   {'clouds': {'all': 76},
#    'dt': 1634515200,
#    'dt_txt': '2021-10-18 00:00:00',
#    'main': {'feels_like': 281.57,
#     'grnd_level': 1019,
#     'humidity': 37,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'temp': 282.14,
#     'temp_kf': 0,
#     'temp_max': 282.14,
#     'temp_min': 282.14},
#    'pop': 0.04,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'broken clouds',
#      'icon': '04d',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 135, 'gust': 2.49, 'speed': 1.57}},
#   {'clouds': {'all': 88},
#    'dt': 1634526000,
#    'dt_txt': '2021-10-18 03:00:00',
#    'main': {'feels_like': 284.71,
#     'grnd_level': 1017,
#     'humidity': 42,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'temp': 286.25,
#     'temp_kf': 0,
#     'temp_max': 286.25,
#     'temp_min': 286.25},
#    'pop': 0.08,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'overcast clouds',
#      'icon': '04d',
#      'id': 804,
#      'main': 'Clouds'}],
#    'wind': {'deg': 181, 'gust': 2.66, 'speed': 1.81}},
#   {'clouds': {'all': 65},
#    'dt': 1634536800,
#    'dt_txt': '2021-10-18 06:00:00',
#    'main': {'feels_like': 287.11,
#     'grnd_level': 1015,
#     'humidity': 48,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'temp': 288.29,
#     'temp_kf': 0,
#     'temp_max': 288.29,
#     'temp_min': 288.29},
#    'pop': 0.04,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'broken clouds',
#      'icon': '04d',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 241, 'gust': 4.79, 'speed': 3.07}},
#   {'clouds': {'all': 45},
#    'dt': 1634547600,
#    'dt_txt': '2021-10-18 09:00:00',
#    'main': {'feels_like': 286,
#     'grnd_level': 1015,
#     'humidity': 55,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'temp': 287.11,
#     'temp_kf': 0,
#     'temp_max': 287.11,
#     'temp_min': 287.11},
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03n',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 231, 'gust': 5.51, 'speed': 2.61}},
#   {'clouds': {'all': 28},
#    'dt': 1634558400,
#    'dt_txt': '2021-10-18 12:00:00',
#    'main': {'feels_like': 284.98,
#     'grnd_level': 1015,
#     'humidity': 56,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'temp': 286.16,
#     'temp_kf': 0,
#     'temp_max': 286.16,
#     'temp_min': 286.16},
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03n',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 229, 'gust': 2.88, 'speed': 1.37}},
#   {'clouds': {'all': 18},
#    'dt': 1634569200,
#    'dt_txt': '2021-10-18 15:00:00',
#    'main': {'feels_like': 284.4,
#     'grnd_level': 1014,
#     'humidity': 59,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'temp': 285.56,
#     'temp_kf': 0,
#     'temp_max': 285.56,
#     'temp_min': 285.56},
#    'pop': 0.23,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'few clouds',
#      'icon': '02n',
#      'id': 801,
#      'main': 'Clouds'}],
#    'wind': {'deg': 208, 'gust': 3.95, 'speed': 1.71}},
#   {'clouds': {'all': 59},
#    'dt': 1634580000,
#    'dt_txt': '2021-10-18 18:00:00',
#    'main': {'feels_like': 284.12,
#     'grnd_level': 1014,
#     'humidity': 78,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'temp': 284.86,
#     'temp_kf': 0,
#     'temp_max': 284.86,
#     'temp_min': 284.86},
#    'pop': 0.8,
#    'rain': {'3h': 1.05},
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'light rain',
#      'icon': '10n',
#      'id': 500,
#      'main': 'Rain'}],
#    'wind': {'deg': 330, 'gust': 6.11, 'speed': 1.93}},
#   {'clouds': {'all': 24},
#    'dt': 1634590800,
#    'dt_txt': '2021-10-18 21:00:00',
#    'main': {'feels_like': 280.37,
#     'grnd_level': 1015,
#     'humidity': 71,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'temp': 282.58,
#     'temp_kf': 0,
#     'temp_max': 282.58,
#     'temp_min': 282.58},
#    'pop': 0.22,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'few clouds',
#      'icon': '02n',
#      'id': 801,
#      'main': 'Clouds'}],
#    'wind': {'deg': 305, 'gust': 8.91, 'speed': 4.17}},
#   {'clouds': {'all': 12},
#    'dt': 1634601600,
#    'dt_txt': '2021-10-19 00:00:00',
#    'main': {'feels_like': 279.76,
#     'grnd_level': 1016,
#     'humidity': 42,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'temp': 282.09,
#     'temp_kf': 0,
#     'temp_max': 282.09,
#     'temp_min': 282.09},
#    'pop': 0.18,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'few clouds',
#      'icon': '02d',
#      'id': 801,
#      'main': 'Clouds'}],
#    'wind': {'deg': 313, 'gust': 6.71, 'speed': 4.19}},
#   {'clouds': {'all': 0},
#    'dt': 1634612400,
#    'dt_txt': '2021-10-19 03:00:00',
#    'main': {'feels_like': 283.63,
#     'grnd_level': 1016,
#     'humidity': 27,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'temp': 285.62,
#     'temp_kf': 0,
#     'temp_max': 285.62,
#     'temp_min': 285.62},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 323, 'gust': 5.94, 'speed': 4.3}},
#   {'clouds': {'all': 0},
#    'dt': 1634623200,
#    'dt_txt': '2021-10-19 06:00:00',
#    'main': {'feels_like': 284.69,
#     'grnd_level': 1015,
#     'humidity': 26,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'temp': 286.61,
#     'temp_kf': 0,
#     'temp_max': 286.61,
#     'temp_min': 286.61},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 329, 'gust': 5.41, 'speed': 4.6}},
#   {'clouds': {'all': 0},
#    'dt': 1634634000,
#    'dt_txt': '2021-10-19 09:00:00',
#    'main': {'feels_like': 282.95,
#     'grnd_level': 1016,
#     'humidity': 36,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'temp': 284.79,
#     'temp_kf': 0,
#     'temp_max': 284.79,
#     'temp_min': 284.79},
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 324, 'gust': 4.55, 'speed': 3.97}},
#   {'clouds': {'all': 0},
#    'dt': 1634644800,
#    'dt_txt': '2021-10-19 12:00:00',
#    'main': {'feels_like': 281.46,
#     'grnd_level': 1018,
#     'humidity': 40,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'temp': 283.34,
#     'temp_kf': 0,
#     'temp_max': 283.34,
#     'temp_min': 283.34},
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 332, 'gust': 2.49, 'speed': 1.47}},
#   {'clouds': {'all': 1},
#    'dt': 1634655600,
#    'dt_txt': '2021-10-19 15:00:00',
#    'main': {'feels_like': 282.52,
#     'grnd_level': 1018,
#     'humidity': 44,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'temp': 282.52,
#     'temp_kf': 0,
#     'temp_max': 282.52,
#     'temp_min': 282.52},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 17, 'gust': 1.39, 'speed': 0.87}},
#   {'clouds': {'all': 7},
#    'dt': 1634666400,
#    'dt_txt': '2021-10-19 18:00:00',
#    'main': {'feels_like': 281.7,
#     'grnd_level': 1018,
#     'humidity': 55,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'temp': 281.7,
#     'temp_kf': 0,
#     'temp_max': 281.7,
#     'temp_min': 281.7},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 60, 'gust': 1.21, 'speed': 0.8}},
#   {'clouds': {'all': 47},
#    'dt': 1634677200,
#    'dt_txt': '2021-10-19 21:00:00',
#    'main': {'feels_like': 280.98,
#     'grnd_level': 1018,
#     'humidity': 64,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'temp': 280.98,
#     'temp_kf': 0,
#     'temp_max': 280.98,
#     'temp_min': 280.98},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03d',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 62, 'gust': 1.39, 'speed': 1.02}},
#   {'clouds': {'all': 30},
#    'dt': 1634688000,
#    'dt_txt': '2021-10-20 00:00:00',
#    'main': {'feels_like': 282.93,
#     'grnd_level': 1019,
#     'humidity': 57,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'temp': 282.93,
#     'temp_kf': 0,
#     'temp_max': 282.93,
#     'temp_min': 282.93},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03d',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 95, 'gust': 0.98, 'speed': 0.86}},
#   {'clouds': {'all': 27},
#    'dt': 1634698800,
#    'dt_txt': '2021-10-20 03:00:00',
#    'main': {'feels_like': 285.09,
#     'grnd_level': 1018,
#     'humidity': 38,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'temp': 286.69,
#     'temp_kf': 0,
#     'temp_max': 286.69,
#     'temp_min': 286.69},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03d',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 263, 'gust': 1.81, 'speed': 1.54}},
#   {'clouds': {'all': 37},
#    'dt': 1634709600,
#    'dt_txt': '2021-10-20 06:00:00',
#    'main': {'feels_like': 285.92,
#     'grnd_level': 1016,
#     'humidity': 31,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'temp': 287.61,
#     'temp_kf': 0,
#     'temp_max': 287.61,
#     'temp_min': 287.61},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03d',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 272, 'gust': 3.43, 'speed': 3.82}}],
#  'message': 0}

# %%
for city in cities:
    weather_dict[city] = city_forecast(city)
